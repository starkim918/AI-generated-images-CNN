# %% [markdown]
# # CSCI 575 Final Project: Real/AI-Generated Image Classifier

# %% [markdown]
# Imports/Setup

# %%
import matplotlib.pyplot as plt
import numpy
import tensorflow
import time

numpy.random.seed(0)
tensorflow.random.set_seed(0)
# %matplotlib inline
verbose = 2 # 0==no output, 1==accuracy/loss output, 2==progress bar output

# %% [markdown]
# Create helper function to plot results of our model training

# %%
def plot_results(history):
    epoch_num = numpy.arange(1, len(history.history['loss'])+1)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epoch_num, history.history['loss'], label='training_loss')
    plt.plot(epoch_num, history.history['val_loss'], label='test_loss')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epoch_num, history.history['accuracy'], label='training_accuracy')
    plt.plot(epoch_num, history.history['val_accuracy'], label='test_accuracy')
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)

# %% [markdown]
# Load the AI/Real Images data

# %%
# Load data
CLASS_NAMES = ['FAKE','REAL']

training_dataset = tensorflow.keras.utils.image_dataset_from_directory(
    directory = 'data/train',
    labels = 'inferred',
    label_mode = 'binary',
    class_names = CLASS_NAMES,
    color_mode = 'rgb',
    batch_size = 32,
    image_size=(64,64),
    shuffle=True,
    seed=99,
)

testing_dataset = tensorflow.keras.utils.image_dataset_from_directory(
    directory = 'data/test',
    labels = 'inferred',
    label_mode = 'binary',
    class_names = CLASS_NAMES,
    color_mode = 'rgb',
    batch_size = 32,
    image_size=(64,64),
    shuffle=True,
    seed=99,
)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.

# %% [markdown]
# Visualize dataset

# %%
plt.figure(figsize = (12,12))
for image, label in training_dataset.take(1):
    for i in range(16):
        ax = plt.subplot(4,4,i+1)
        plt.imshow(image[i]/255.)
        plt.title(CLASS_NAMES[int(label[i])])
        plt.axis('off')

# %% [markdown]
# Baseline Model (from CSCI470 resource-- see references folder)

# %%
num_kernels = 4
dense_layer_neurons = 64
kernels_size = (3, 3)
model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu', input_shape=(64, 64, 3)),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu'),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Flatten(),

    tensorflow.keras.layers.Dense(dense_layer_neurons, activation='relu'),
    tensorflow.keras.layers.Dense(10)
])

model.compile(
    loss=tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tensorflow.keras.optimizers.legacy.Adam(0.001),
    metrics=['accuracy'],
)

epochs = 50
t = time.time()
history = model.fit(training_dataset.take(epochs),
                    epochs=epochs,
                    validation_data=testing_dataset,
                    verbose=verbose)
print('Training duration: %f seconds.' % (time.time() - t))

plot_results(history)
# Out:
# Epoch 1/50
# 50/50 - 2s - loss: 1.9791 - accuracy: 0.5219 - val_loss: 1.3058 - val_accuracy: 0.5778 - 2s/epoch - 45ms/step
# Epoch 2/50
# 50/50 - 2s - loss: 0.8469 - accuracy: 0.6894 - val_loss: 1.0200 - val_accuracy: 0.6152 - 2s/epoch - 44ms/step
# Epoch 3/50
# 50/50 - 2s - loss: 0.5613 - accuracy: 0.7656 - val_loss: 0.9624 - val_accuracy: 0.6271 - 2s/epoch - 45ms/step
# Epoch 4/50
# 50/50 - 3s - loss: 0.4085 - accuracy: 0.8231 - val_loss: 0.9874 - val_accuracy: 0.6309 - 3s/epoch - 59ms/step
# Epoch 5/50
# 50/50 - 2s - loss: 0.3056 - accuracy: 0.8800 - val_loss: 1.0176 - val_accuracy: 0.6341 - 2s/epoch - 43ms/step
# Epoch 6/50
# 50/50 - 2s - loss: 0.2445 - accuracy: 0.9006 - val_loss: 1.0905 - val_accuracy: 0.6444 - 2s/epoch - 43ms/step
# Epoch 7/50
# 50/50 - 2s - loss: 0.1932 - accuracy: 0.9300 - val_loss: 1.1352 - val_accuracy: 0.6543 - 2s/epoch - 42ms/step
# Epoch 8/50
# 50/50 - 2s - loss: 0.1371 - accuracy: 0.9563 - val_loss: 1.2090 - val_accuracy: 0.6560 - 2s/epoch - 43ms/step
# Epoch 9/50
# 50/50 - 2s - loss: 0.1112 - accuracy: 0.9644 - val_loss: 1.3292 - val_accuracy: 0.6461 - 2s/epoch - 43ms/step
# Epoch 10/50
# 50/50 - 2s - loss: 0.0939 - accuracy: 0.9706 - val_loss: 1.3802 - val_accuracy: 0.6593 - 2s/epoch - 44ms/step
# Epoch 11/50
# 50/50 - 2s - loss: 0.0771 - accuracy: 0.9775 - val_loss: 1.4201 - val_accuracy: 0.6646 - 2s/epoch - 42ms/step
# Epoch 12/50
# 50/50 - 2s - loss: 0.0637 - accuracy: 0.9831 - val_loss: 1.5079 - val_accuracy: 0.6691 - 2s/epoch - 42ms/step
# Epoch 13/50
# 50/50 - 2s - loss: 0.0573 - accuracy: 0.9881 - val_loss: 1.8228 - val_accuracy: 0.6418 - 2s/epoch - 42ms/step
# Epoch 14/50
# 50/50 - 2s - loss: 0.0884 - accuracy: 0.9744 - val_loss: 1.6938 - val_accuracy: 0.6714 - 2s/epoch - 41ms/step
# Epoch 15/50
# 50/50 - 2s - loss: 0.0554 - accuracy: 0.9875 - val_loss: 1.8999 - val_accuracy: 0.6690 - 2s/epoch - 44ms/step
# Epoch 16/50
# 50/50 - 3s - loss: 0.0697 - accuracy: 0.9850 - val_loss: 1.7405 - val_accuracy: 0.6590 - 3s/epoch - 51ms/step
# Epoch 17/50
# 50/50 - 2s - loss: 0.0268 - accuracy: 0.9969 - val_loss: 1.8080 - val_accuracy: 0.6662 - 2s/epoch - 46ms/step
# Epoch 18/50
# 50/50 - 2s - loss: 0.0178 - accuracy: 0.9981 - val_loss: 1.9068 - val_accuracy: 0.6633 - 2s/epoch - 44ms/step
# Epoch 19/50
# 50/50 - 2s - loss: 0.0137 - accuracy: 0.9987 - val_loss: 2.0053 - val_accuracy: 0.6653 - 2s/epoch - 42ms/step
# Epoch 20/50
# 50/50 - 2s - loss: 0.0133 - accuracy: 0.9994 - val_loss: 2.0660 - val_accuracy: 0.6670 - 2s/epoch - 45ms/step
# Epoch 21/50
# 50/50 - 2s - loss: 0.0305 - accuracy: 0.9975 - val_loss: 2.1564 - val_accuracy: 0.6617 - 2s/epoch - 43ms/step
# Epoch 22/50
# 50/50 - 2s - loss: 0.0376 - accuracy: 0.9906 - val_loss: 1.9946 - val_accuracy: 0.6701 - 2s/epoch - 44ms/step
# Epoch 23/50
# 50/50 - 2s - loss: 0.1176 - accuracy: 0.9669 - val_loss: 2.1575 - val_accuracy: 0.6431 - 2s/epoch - 42ms/step
# Epoch 24/50
# 50/50 - 2s - loss: 0.1572 - accuracy: 0.9525 - val_loss: 1.9063 - val_accuracy: 0.6442 - 2s/epoch - 42ms/step
# Epoch 25/50
# 50/50 - 2s - loss: 0.1238 - accuracy: 0.9669 - val_loss: 1.7588 - val_accuracy: 0.6525 - 2s/epoch - 49ms/step
# Epoch 26/50
# 50/50 - 2s - loss: 0.0383 - accuracy: 0.9900 - val_loss: 1.9755 - val_accuracy: 0.6687 - 2s/epoch - 44ms/step
# Epoch 27/50
# 50/50 - 2s - loss: 0.0279 - accuracy: 0.9919 - val_loss: 2.0510 - val_accuracy: 0.6701 - 2s/epoch - 44ms/step
# Epoch 28/50
# 50/50 - 2s - loss: 0.0287 - accuracy: 0.9912 - val_loss: 2.1217 - val_accuracy: 0.6704 - 2s/epoch - 42ms/step
# Epoch 29/50
# 50/50 - 2s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 2.1395 - val_accuracy: 0.6710 - 2s/epoch - 46ms/step
# Epoch 30/50
# 50/50 - 2s - loss: 0.0103 - accuracy: 0.9994 - val_loss: 2.1979 - val_accuracy: 0.6752 - 2s/epoch - 43ms/step
# Epoch 31/50
# 50/50 - 2s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.2653 - val_accuracy: 0.6771 - 2s/epoch - 41ms/step
# Epoch 32/50
# 50/50 - 2s - loss: 0.0069 - accuracy: 0.9994 - val_loss: 2.5247 - val_accuracy: 0.6687 - 2s/epoch - 42ms/step
# Epoch 33/50
# 50/50 - 2s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.3448 - val_accuracy: 0.6701 - 2s/epoch - 42ms/step
# Epoch 34/50
# 50/50 - 2s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 2.4546 - val_accuracy: 0.6680 - 2s/epoch - 42ms/step
# Epoch 35/50
# 50/50 - 2s - loss: 0.0142 - accuracy: 0.9969 - val_loss: 2.4026 - val_accuracy: 0.6641 - 2s/epoch - 43ms/step
# Epoch 36/50
# 50/50 - 2s - loss: 0.0470 - accuracy: 0.9862 - val_loss: 2.5176 - val_accuracy: 0.6565 - 2s/epoch - 42ms/step
# Epoch 37/50
# 50/50 - 2s - loss: 0.0258 - accuracy: 0.9919 - val_loss: 2.4142 - val_accuracy: 0.6659 - 2s/epoch - 41ms/step
# Epoch 38/50
# 50/50 - 2s - loss: 0.0122 - accuracy: 0.9981 - val_loss: 2.4895 - val_accuracy: 0.6571 - 2s/epoch - 41ms/step
# Epoch 39/50
# 50/50 - 2s - loss: 0.0252 - accuracy: 0.9950 - val_loss: 2.5857 - val_accuracy: 0.6672 - 2s/epoch - 43ms/step
# Epoch 40/50
# 50/50 - 2s - loss: 0.0545 - accuracy: 0.9912 - val_loss: 2.6503 - val_accuracy: 0.6660 - 2s/epoch - 44ms/step
# Epoch 41/50
# 50/50 - 2s - loss: 0.0429 - accuracy: 0.9881 - val_loss: 2.4351 - val_accuracy: 0.6622 - 2s/epoch - 47ms/step
# Epoch 42/50
# 50/50 - 2s - loss: 0.0419 - accuracy: 0.9906 - val_loss: 2.7381 - val_accuracy: 0.6514 - 2s/epoch - 48ms/step
# Epoch 43/50
# 50/50 - 2s - loss: 0.0553 - accuracy: 0.9837 - val_loss: 2.5439 - val_accuracy: 0.6593 - 2s/epoch - 47ms/step
# Epoch 44/50
# 50/50 - 2s - loss: 0.0356 - accuracy: 0.9894 - val_loss: 2.3927 - val_accuracy: 0.6648 - 2s/epoch - 46ms/step
# Epoch 45/50
# 50/50 - 2s - loss: 0.0220 - accuracy: 0.9956 - val_loss: 2.5661 - val_accuracy: 0.6571 - 2s/epoch - 49ms/step
# Epoch 46/50
# 50/50 - 3s - loss: 0.0164 - accuracy: 0.9969 - val_loss: 2.5381 - val_accuracy: 0.6674 - 3s/epoch - 50ms/step
# Epoch 47/50
# 50/50 - 2s - loss: 0.0147 - accuracy: 0.9962 - val_loss: 2.5259 - val_accuracy: 0.6687 - 2s/epoch - 42ms/step
# Epoch 48/50
# 50/50 - 2s - loss: 0.0153 - accuracy: 0.9975 - val_loss: 2.5669 - val_accuracy: 0.6719 - 2s/epoch - 43ms/step
# Epoch 49/50
# 50/50 - 2s - loss: 0.0191 - accuracy: 0.9956 - val_loss: 2.4889 - val_accuracy: 0.6708 - 2s/epoch - 44ms/step
# Epoch 50/50
# 50/50 - 2s - loss: 0.0112 - accuracy: 0.9981 - val_loss: 2.5134 - val_accuracy: 0.6712 - 2s/epoch - 41ms/step
# Training duration: 110.513811 seconds.

# %% [markdown]
# Modification 1: Add Batch Normalization layers

# %%
num_kernels = 4
dense_layer_neurons = 64
kernels_size = (3, 3)
model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu', input_shape=(64, 64, 3)),
    # New code here
    tensorflow.keras.layers.BatchNormalization(),
    # End new code
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu'),
    # New code here
    tensorflow.keras.layers.BatchNormalization(),
    # End new code
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Flatten(),

    tensorflow.keras.layers.Dense(dense_layer_neurons, activation='relu'),
    tensorflow.keras.layers.Dense(10)
])

model.compile(
    loss=tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tensorflow.keras.optimizers.legacy.Adam(0.001),
    metrics=['accuracy'],
)

epochs = 50
t = time.time()
history = model.fit(training_dataset.take(epochs),
                    epochs=epochs,
                    validation_data=testing_dataset,
                    verbose=verbose)
print('Training duration: %f seconds.' % (time.time() - t))

plot_results(history)
# Out:
# Epoch 1/50
# 50/50 - 3s - loss: 1.1846 - accuracy: 0.5600 - val_loss: 0.7028 - val_accuracy: 0.6367 - 3s/epoch - 54ms/step
# Epoch 2/50
# 50/50 - 2s - loss: 0.5192 - accuracy: 0.7500 - val_loss: 0.5880 - val_accuracy: 0.6926 - 2s/epoch - 49ms/step
# Epoch 3/50
# 50/50 - 3s - loss: 0.3949 - accuracy: 0.8256 - val_loss: 0.6186 - val_accuracy: 0.6872 - 3s/epoch - 51ms/step
# Epoch 4/50
# 50/50 - 3s - loss: 0.3055 - accuracy: 0.8788 - val_loss: 0.5805 - val_accuracy: 0.7240 - 3s/epoch - 53ms/step
# Epoch 5/50
# 50/50 - 3s - loss: 0.2516 - accuracy: 0.9081 - val_loss: 0.6206 - val_accuracy: 0.7189 - 3s/epoch - 57ms/step
# Epoch 6/50
# 50/50 - 3s - loss: 0.1908 - accuracy: 0.9362 - val_loss: 0.6575 - val_accuracy: 0.7211 - 3s/epoch - 57ms/step
# Epoch 7/50
# 50/50 - 3s - loss: 0.1627 - accuracy: 0.9444 - val_loss: 0.7042 - val_accuracy: 0.7200 - 3s/epoch - 52ms/step
# Epoch 8/50
# 50/50 - 2s - loss: 0.1415 - accuracy: 0.9525 - val_loss: 0.6990 - val_accuracy: 0.7231 - 2s/epoch - 50ms/step
# Epoch 9/50
# 50/50 - 3s - loss: 0.0968 - accuracy: 0.9769 - val_loss: 0.6907 - val_accuracy: 0.7355 - 3s/epoch - 53ms/step
# Epoch 10/50
# 50/50 - 2s - loss: 0.0863 - accuracy: 0.9831 - val_loss: 0.7084 - val_accuracy: 0.7424 - 2s/epoch - 50ms/step
# Epoch 11/50
# 50/50 - 3s - loss: 0.0616 - accuracy: 0.9875 - val_loss: 0.7126 - val_accuracy: 0.7414 - 3s/epoch - 56ms/step
# Epoch 12/50
# 50/50 - 3s - loss: 0.0477 - accuracy: 0.9912 - val_loss: 0.7204 - val_accuracy: 0.7490 - 3s/epoch - 53ms/step
# Epoch 13/50
# 50/50 - 2s - loss: 0.0409 - accuracy: 0.9975 - val_loss: 0.7404 - val_accuracy: 0.7525 - 2s/epoch - 50ms/step
# Epoch 14/50
# 50/50 - 2s - loss: 0.0308 - accuracy: 0.9962 - val_loss: 0.7658 - val_accuracy: 0.7531 - 2s/epoch - 48ms/step
# Epoch 15/50
# 50/50 - 2s - loss: 0.0239 - accuracy: 0.9969 - val_loss: 0.7708 - val_accuracy: 0.7600 - 2s/epoch - 49ms/step
# Epoch 16/50
# 50/50 - 2s - loss: 0.0204 - accuracy: 0.9987 - val_loss: 0.7967 - val_accuracy: 0.7540 - 2s/epoch - 48ms/step
# Epoch 17/50
# 50/50 - 2s - loss: 0.0195 - accuracy: 0.9981 - val_loss: 0.8326 - val_accuracy: 0.7481 - 2s/epoch - 48ms/step
# Epoch 18/50
# 50/50 - 2s - loss: 0.0175 - accuracy: 0.9994 - val_loss: 0.8504 - val_accuracy: 0.7546 - 2s/epoch - 49ms/step
# Epoch 19/50
# 50/50 - 2s - loss: 0.0273 - accuracy: 0.9962 - val_loss: 0.9316 - val_accuracy: 0.7534 - 2s/epoch - 49ms/step
# Epoch 20/50
# 50/50 - 2s - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.8892 - val_accuracy: 0.7505 - 2s/epoch - 49ms/step
# Epoch 21/50
# 50/50 - 2s - loss: 0.0137 - accuracy: 0.9987 - val_loss: 0.8805 - val_accuracy: 0.7570 - 2s/epoch - 47ms/step
# Epoch 22/50
# 50/50 - 2s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.7425 - 2s/epoch - 49ms/step
# Epoch 23/50
# 50/50 - 2s - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.9883 - val_accuracy: 0.7485 - 2s/epoch - 50ms/step
# Epoch 24/50
# 50/50 - 2s - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.9571 - val_accuracy: 0.7560 - 2s/epoch - 49ms/step
# Epoch 25/50
# 50/50 - 3s - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.9538 - val_accuracy: 0.7582 - 3s/epoch - 50ms/step
# Epoch 26/50
# 50/50 - 2s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.9761 - val_accuracy: 0.7556 - 2s/epoch - 48ms/step
# Epoch 27/50
# 50/50 - 3s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9648 - val_accuracy: 0.7564 - 3s/epoch - 50ms/step
# Epoch 28/50
# 50/50 - 2s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.7537 - 2s/epoch - 48ms/step
# Epoch 29/50
# 50/50 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0053 - val_accuracy: 0.7540 - 2s/epoch - 48ms/step
# Epoch 30/50
# 50/50 - 3s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0219 - val_accuracy: 0.7555 - 3s/epoch - 50ms/step
# Epoch 31/50
# 50/50 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0350 - val_accuracy: 0.7532 - 2s/epoch - 48ms/step
# Epoch 32/50
# 50/50 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1058 - val_accuracy: 0.7483 - 2s/epoch - 48ms/step
# Epoch 33/50
# 50/50 - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.0707 - val_accuracy: 0.7539 - 3s/epoch - 53ms/step
# Epoch 34/50
# 50/50 - 3s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0734 - val_accuracy: 0.7545 - 3s/epoch - 51ms/step
# Epoch 35/50
# 50/50 - 3s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0593 - val_accuracy: 0.7565 - 3s/epoch - 51ms/step
# Epoch 36/50
# 50/50 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0602 - val_accuracy: 0.7570 - 2s/epoch - 50ms/step
# Epoch 37/50
# 50/50 - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.0684 - val_accuracy: 0.7553 - 3s/epoch - 55ms/step
# Epoch 38/50
# 50/50 - 3s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0894 - val_accuracy: 0.7554 - 3s/epoch - 51ms/step
# Epoch 39/50
# 50/50 - 2s - loss: 0.0058 - accuracy: 0.9994 - val_loss: 1.0855 - val_accuracy: 0.7615 - 2s/epoch - 49ms/step
# Epoch 40/50
# 50/50 - 2s - loss: 0.0184 - accuracy: 0.9962 - val_loss: 1.3321 - val_accuracy: 0.7272 - 2s/epoch - 50ms/step
# Epoch 41/50
# 50/50 - 2s - loss: 0.0764 - accuracy: 0.9719 - val_loss: 1.3028 - val_accuracy: 0.7255 - 2s/epoch - 50ms/step
# Epoch 42/50
# 50/50 - 2s - loss: 0.1259 - accuracy: 0.9575 - val_loss: 1.5851 - val_accuracy: 0.7248 - 2s/epoch - 49ms/step
# Epoch 43/50
# 50/50 - 3s - loss: 0.1553 - accuracy: 0.9406 - val_loss: 1.4212 - val_accuracy: 0.7485 - 3s/epoch - 50ms/step
# Epoch 44/50
# 50/50 - 2s - loss: 0.0593 - accuracy: 0.9825 - val_loss: 1.3193 - val_accuracy: 0.7537 - 2s/epoch - 48ms/step
# Epoch 45/50
# 50/50 - 2s - loss: 0.0336 - accuracy: 0.9869 - val_loss: 1.1741 - val_accuracy: 0.7534 - 2s/epoch - 49ms/step
# Epoch 46/50
# 50/50 - 2s - loss: 0.0166 - accuracy: 0.9944 - val_loss: 1.2173 - val_accuracy: 0.7490 - 2s/epoch - 50ms/step
# Epoch 47/50
# 50/50 - 2s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.1862 - val_accuracy: 0.7606 - 2s/epoch - 49ms/step
# Epoch 48/50
# 50/50 - 3s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2102 - val_accuracy: 0.7602 - 3s/epoch - 51ms/step
# Epoch 49/50
# 50/50 - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.2544 - val_accuracy: 0.7560 - 3s/epoch - 57ms/step
# Epoch 50/50
# 50/50 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2297 - val_accuracy: 0.7584 - 2s/epoch - 50ms/step
# Training duration: 126.216219 seconds.

# %% [markdown]
# Modification 2: Adding more convoluational, batch normalization, and max pooling layers

# %%
num_kernels = 4
dense_layer_neurons = 64
kernels_size = (3, 3)
model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu', input_shape=(64, 64, 3)),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu'),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),
    
    # New code here
    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu'),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),

    tensorflow.keras.layers.Conv2D(num_kernels, kernels_size, activation='relu'),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.MaxPool2D(pool_size=(2, 2), padding='same'),
    # End new code

    tensorflow.keras.layers.Flatten(),

    tensorflow.keras.layers.Dense(dense_layer_neurons, activation='relu'),
    tensorflow.keras.layers.Dense(10)
])

model.compile(
    loss=tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tensorflow.keras.optimizers.legacy.Adam(0.001),
    metrics=['accuracy'],
)

epochs = 50
t = time.time()
history = model.fit(training_dataset.take(epochs),
                    epochs=epochs,
                    validation_data=testing_dataset,
                    verbose=verbose)
print('Training duration: %f seconds.' % (time.time() - t))

plot_results(history)
# Out:
# Epoch 1/50
# 50/50 - 3s - loss: 1.2620 - accuracy: 0.5450 - val_loss: 0.8834 - val_accuracy: 0.6010 - 3s/epoch - 58ms/step
# Epoch 2/50
# 50/50 - 3s - loss: 0.6731 - accuracy: 0.7219 - val_loss: 0.8374 - val_accuracy: 0.6865 - 3s/epoch - 51ms/step
# Epoch 3/50
# 50/50 - 3s - loss: 0.5649 - accuracy: 0.7306 - val_loss: 0.6910 - val_accuracy: 0.6934 - 3s/epoch - 55ms/step
# Epoch 4/50
# 50/50 - 3s - loss: 0.5214 - accuracy: 0.7600 - val_loss: 0.5843 - val_accuracy: 0.7203 - 3s/epoch - 52ms/step
# Epoch 5/50
# 50/50 - 3s - loss: 0.4917 - accuracy: 0.7731 - val_loss: 0.5344 - val_accuracy: 0.7491 - 3s/epoch - 52ms/step
# Epoch 6/50
# 50/50 - 3s - loss: 0.4694 - accuracy: 0.7794 - val_loss: 0.5144 - val_accuracy: 0.7560 - 3s/epoch - 52ms/step
# Epoch 7/50
# 50/50 - 3s - loss: 0.4679 - accuracy: 0.7931 - val_loss: 0.5805 - val_accuracy: 0.7243 - 3s/epoch - 56ms/step
# Epoch 8/50
# 50/50 - 3s - loss: 0.4655 - accuracy: 0.7806 - val_loss: 0.5756 - val_accuracy: 0.7237 - 3s/epoch - 53ms/step
# Epoch 9/50
# 50/50 - 3s - loss: 0.4467 - accuracy: 0.7919 - val_loss: 0.5026 - val_accuracy: 0.7617 - 3s/epoch - 58ms/step
# Epoch 10/50
# 50/50 - 3s - loss: 0.4373 - accuracy: 0.7937 - val_loss: 0.5102 - val_accuracy: 0.7621 - 3s/epoch - 53ms/step
# Epoch 11/50
# 50/50 - 3s - loss: 0.4200 - accuracy: 0.8087 - val_loss: 0.5694 - val_accuracy: 0.7376 - 3s/epoch - 53ms/step
# Epoch 12/50
# 50/50 - 3s - loss: 0.4194 - accuracy: 0.8094 - val_loss: 0.5227 - val_accuracy: 0.7447 - 3s/epoch - 53ms/step
# Epoch 13/50
# 50/50 - 3s - loss: 0.3996 - accuracy: 0.8163 - val_loss: 0.5080 - val_accuracy: 0.7696 - 3s/epoch - 53ms/step
# Epoch 14/50
# 50/50 - 3s - loss: 0.3864 - accuracy: 0.8206 - val_loss: 0.4900 - val_accuracy: 0.7732 - 3s/epoch - 51ms/step
# Epoch 15/50
# 50/50 - 3s - loss: 0.3887 - accuracy: 0.8138 - val_loss: 0.5004 - val_accuracy: 0.7677 - 3s/epoch - 51ms/step
# Epoch 16/50
# 50/50 - 3s - loss: 0.3771 - accuracy: 0.8144 - val_loss: 0.4930 - val_accuracy: 0.7747 - 3s/epoch - 53ms/step
# Epoch 17/50
# 50/50 - 3s - loss: 0.3774 - accuracy: 0.8263 - val_loss: 0.5027 - val_accuracy: 0.7707 - 3s/epoch - 51ms/step
# Epoch 18/50
# 50/50 - 3s - loss: 0.3594 - accuracy: 0.8350 - val_loss: 0.5556 - val_accuracy: 0.7534 - 3s/epoch - 52ms/step
# Epoch 19/50
# 50/50 - 3s - loss: 0.3473 - accuracy: 0.8525 - val_loss: 0.5894 - val_accuracy: 0.7339 - 3s/epoch - 52ms/step
# Epoch 20/50
# 50/50 - 3s - loss: 0.3229 - accuracy: 0.8650 - val_loss: 0.5594 - val_accuracy: 0.7579 - 3s/epoch - 53ms/step
# Epoch 21/50
# 50/50 - 3s - loss: 0.3287 - accuracy: 0.8512 - val_loss: 0.4873 - val_accuracy: 0.7819 - 3s/epoch - 52ms/step
# Epoch 22/50
# 50/50 - 3s - loss: 0.3402 - accuracy: 0.8494 - val_loss: 0.8196 - val_accuracy: 0.6462 - 3s/epoch - 53ms/step
# Epoch 23/50
# 50/50 - 3s - loss: 0.3437 - accuracy: 0.8369 - val_loss: 0.4863 - val_accuracy: 0.7847 - 3s/epoch - 51ms/step
# Epoch 24/50
# 50/50 - 3s - loss: 0.3148 - accuracy: 0.8606 - val_loss: 0.5387 - val_accuracy: 0.7578 - 3s/epoch - 52ms/step
# Epoch 25/50
# 50/50 - 3s - loss: 0.3129 - accuracy: 0.8669 - val_loss: 0.5035 - val_accuracy: 0.7771 - 3s/epoch - 51ms/step
# Epoch 26/50
# 50/50 - 3s - loss: 0.3166 - accuracy: 0.8600 - val_loss: 0.5400 - val_accuracy: 0.7602 - 3s/epoch - 53ms/step
# Epoch 27/50
# 50/50 - 3s - loss: 0.3175 - accuracy: 0.8587 - val_loss: 0.4962 - val_accuracy: 0.7786 - 3s/epoch - 52ms/step
# Epoch 28/50
# 50/50 - 3s - loss: 0.2944 - accuracy: 0.8744 - val_loss: 0.5258 - val_accuracy: 0.7721 - 3s/epoch - 52ms/step
# Epoch 29/50
# 50/50 - 3s - loss: 0.2767 - accuracy: 0.8800 - val_loss: 0.5031 - val_accuracy: 0.7833 - 3s/epoch - 52ms/step
# Epoch 30/50
# 50/50 - 3s - loss: 0.2673 - accuracy: 0.8906 - val_loss: 0.5773 - val_accuracy: 0.7642 - 3s/epoch - 51ms/step
# Epoch 31/50
# 50/50 - 3s - loss: 0.2783 - accuracy: 0.8788 - val_loss: 0.5457 - val_accuracy: 0.7746 - 3s/epoch - 51ms/step
# Epoch 32/50
# 50/50 - 3s - loss: 0.3010 - accuracy: 0.8706 - val_loss: 0.5052 - val_accuracy: 0.7840 - 3s/epoch - 53ms/step
# Epoch 33/50
# 50/50 - 3s - loss: 0.2706 - accuracy: 0.8838 - val_loss: 0.6226 - val_accuracy: 0.7544 - 3s/epoch - 52ms/step
# Epoch 34/50
# 50/50 - 3s - loss: 0.2391 - accuracy: 0.8981 - val_loss: 0.5454 - val_accuracy: 0.7736 - 3s/epoch - 61ms/step
# Epoch 35/50
# 50/50 - 3s - loss: 0.2794 - accuracy: 0.8750 - val_loss: 0.5488 - val_accuracy: 0.7683 - 3s/epoch - 53ms/step
# Epoch 36/50
# 50/50 - 3s - loss: 0.2497 - accuracy: 0.8888 - val_loss: 0.5299 - val_accuracy: 0.7809 - 3s/epoch - 52ms/step
# Epoch 37/50
# 50/50 - 3s - loss: 0.2461 - accuracy: 0.8963 - val_loss: 0.5381 - val_accuracy: 0.7803 - 3s/epoch - 52ms/step
# Epoch 38/50
# 50/50 - 3s - loss: 0.2469 - accuracy: 0.8956 - val_loss: 0.5332 - val_accuracy: 0.7810 - 3s/epoch - 54ms/step
# Epoch 39/50
# 50/50 - 3s - loss: 0.2249 - accuracy: 0.9000 - val_loss: 0.5989 - val_accuracy: 0.7661 - 3s/epoch - 53ms/step
# Epoch 40/50
# 50/50 - 3s - loss: 0.2438 - accuracy: 0.9069 - val_loss: 0.5890 - val_accuracy: 0.7643 - 3s/epoch - 54ms/step
# Epoch 41/50
# 50/50 - 3s - loss: 0.2472 - accuracy: 0.9050 - val_loss: 0.6267 - val_accuracy: 0.7531 - 3s/epoch - 52ms/step
# Epoch 42/50
# 50/50 - 3s - loss: 0.2208 - accuracy: 0.9112 - val_loss: 0.6347 - val_accuracy: 0.7631 - 3s/epoch - 51ms/step
# Epoch 43/50
# 50/50 - 3s - loss: 0.2245 - accuracy: 0.9119 - val_loss: 0.5491 - val_accuracy: 0.7811 - 3s/epoch - 54ms/step
# Epoch 44/50
# 50/50 - 3s - loss: 0.2074 - accuracy: 0.9237 - val_loss: 0.5765 - val_accuracy: 0.7754 - 3s/epoch - 55ms/step
# Epoch 45/50
# 50/50 - 3s - loss: 0.2248 - accuracy: 0.9050 - val_loss: 0.6418 - val_accuracy: 0.7737 - 3s/epoch - 51ms/step
# Epoch 46/50
# 50/50 - 3s - loss: 0.2109 - accuracy: 0.9150 - val_loss: 0.5674 - val_accuracy: 0.7739 - 3s/epoch - 57ms/step
# Epoch 47/50
# 50/50 - 3s - loss: 0.2096 - accuracy: 0.9200 - val_loss: 0.6166 - val_accuracy: 0.7686 - 3s/epoch - 53ms/step
# Epoch 48/50
# 50/50 - 3s - loss: 0.2491 - accuracy: 0.8988 - val_loss: 0.5749 - val_accuracy: 0.7748 - 3s/epoch - 53ms/step
# Epoch 49/50
# 50/50 - 3s - loss: 0.2201 - accuracy: 0.9212 - val_loss: 0.6060 - val_accuracy: 0.7721 - 3s/epoch - 52ms/step
# Epoch 50/50
# 50/50 - 3s - loss: 0.2183 - accuracy: 0.9175 - val_loss: 0.5716 - val_accuracy: 0.7857 - 3s/epoch - 52ms/step
# Training duration: 134.322049 seconds.

# %% [markdown]
# Making Predictions with the Final Model

# %%
demo_dataset = tensorflow.keras.utils.image_dataset_from_directory(
    directory = 'data/demo',
    labels = 'inferred',
    label_mode = 'binary',
    class_names = CLASS_NAMES,
    color_mode = 'rgb',
    batch_size = 32,
    image_size=(64,64),
    shuffle=True,
    seed=99,
)

def imageToArray(image):
  # Convert the image to a NumPy array and normalize the pixel values (if necessary)
  image_array = numpy.asarray(image)
  image_array = image_array / 255.0  # Normalize the pixel values between 0 and 1

  # Reshape the image array to match the input shape of your model
  image_array = image_array.reshape(64, 64, 3)  # Assumes the input shape is (width, height, 3)

  return image_array

plt.figure(figsize = (12,12))
for image, label in demo_dataset:
    predictions = model.predict(image)
    classes=numpy.argmax(predictions,axis=1)
    for i in range(6):
        ax = plt.subplot(2,3,i+1)
        plt.imshow(image[i]/255.)
        plt.title("Actual: "+CLASS_NAMES[int(label[i])]+"\nPredicted: "+CLASS_NAMES[classes[i]])
        plt.axis('off')
# Out:
# Found 6 files belonging to 2 classes.
# 1/1 [==============================] - 0s 11ms/step
